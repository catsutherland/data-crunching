# %% [markdown]
# # Python Workshop Day 2 - Plotting Data

# %%
# This cell imports the packages that we are going to use today and sets things up for plotting.

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## What is a graph?

# %% [markdown]
# ![2020_google_trends.png](attachment:2020_google_trends.png)

# %% [markdown]
# ## Why do we draw graphs?
#
# * They are much easier to read than long lists of numbers
# * They are a great way to share our data with others
# * They can help us discover interesting things about our data

# %% [markdown]
# # What kind of graphs can we make?
#
# There is an almost endless range of different types of graphs that can be used to display different types of data. We are just going to look at two today. The line graph and the scatter plot.
#
# ![example_graphs-3.png](attachment:example_graphs-3.png)
#
# **Scatter plots** - When two numerical variables are connected we say they are correlated and we can show this on  a scatter. Each observation is represented as a point on a graph with two axes. If one value depends on another, the dependent value is always marked on the vertical axis.
#
# **Line graphs** - A line graph is similar to a scatter plot except that the measurement points are ordered (typically by their x-axis value) and joined with straight lines. A line graph is often used to see changes in data over intervals of time – and the line is often drawn chronologically.

# %% [markdown]
# ## Parts of a graph
#
# It's important that we make our graph easy for other people to understand!
#
# * Always include a title for your graph
# * Always label your axes and include units if they are needed
#
# ![what_is_graph.png](attachment:what_is_graph.png)

# %% [markdown]
# ## Let's plot some of our cancelled operations data!
#
# We are going to read in the **cancellations_scotland_day_2.csv**. This file contains the same data that we looked at on Wednesday with the NAs removed and the CancelledPercent column added (just as your dataframe would have looked after we cleaned it up).

# %%
operations =

# %%
operations.head()

# %% [markdown]
# ### Drawing a line graph
#
# We might want to look at how the number of total operations scheduled changed over time. To do this we would like to use a line graph.
#
#
# We will use seaborn, a python package, to draw our graph using the **lineplot** function:
#
# ```sns.lineplot(data = our_dataframe, x = "our_time_variable", y = "our_numeric_variable")```
#
# We should also add a title to the graph:
#
# ```plt.title("This is the title of this graph)```
#
# And label our x and y axes:
#
# ```plt.xlabel("Our time variable")```
#
# ```plt.ylabel("Our numeric variable")```
#
# We might also want to show the individual data points on our line, we can do this by adding ```marker = 'o'``` to our lineplot call.
#
# ```sns.lineplot(data = our_dataframe, x = "our_time_variable", y = "our_numeric_variable", marker = 'o')```

# %% [markdown]
# ### Lets plot total scheduled operations against time

# %% [markdown]
# ### Something looks weird here!
#
# We need to tell python that our Month column is a date, not a number.
#
# We can do this like so:
#
# ```operations['Month']= pd.to_datetime(operations['Month'], format='%Y%m')```

# %% [markdown]
# Can you think of some reasons for the change in number of total scheduled operations over time?

# %% [markdown]
# ## Your turn!

# %% [markdown]
# ### Plot a line graph showing percentage of scheduled operations that have been cancelled over time
#
# **In the cell below plot a labelled line graph of percentage operations cancelled against time.**
#
#
# <br>
#
# <details>
#
# <summary>Click me for a hint!</summary>
# The columns that you want to use are Month and PercentCancelled.</details>
#
# Can you describe the trend that you see in cancelled operations over time and think of some reasons for this?

# %% [markdown]
# ## Let's investigate a potential reason behind these cancellations

# %% [markdown]
# You have access to a file called **covid_cases_scotland.csv**. It contains the total number of recorded Covid-19 cases in Scotland for each month from July 2020 to May 2022.
#
# **In the code cell below, read in this file and take a look at it.**

# %%
covid_cases =

# %%
covid_cases.head()

# %% [markdown]
# ### Let's format our date column again
#
# Again, we need to tell python that the Month column in our covid_cases dataframe is also a date by formatting it to the datetime type.
#
# So we do just as we did before:
#
# ```covid_cases['Month']= pd.to_datetime(covid_cases['Month'], format='%Y%m')```
#
# Try this yourself in the cell below.

# %%
covid_cases.head()

# %% [markdown]
# ### Plot a line graph showing covid cases over time that have been cancelled over time

# %% [markdown]
# # Are cancelled operations and Covid-19 cases correlated?
#
# ### What is correlation?
#
# If there is a correlation between two sets of data, it means they are connected in some way.
#
# ![correlation.png](attachment:correlation.png)
#
# We can check for correlation using a scatter plot.
#
# Remember, our dependent variable - the value that we think is being affected - always goes on the vertical axis. The variable that we think is causing the effect goes on the x axis.

# %% [markdown]
# ### We need to combine our two separate datasets if we want to plot them on the same graph.
#
# **We want to see what effect an increase in Covid-19 cases has on the percentage of operations that are cancelled.**
#
# To investigate this, we should plot a graph but the two variables we want to plot are in different dataframes!
#
# To make our graph, we need to add the ReportedCases column from our covid_cases dataframe to our operations dataframe.
#
# Rather than trying to copy and paste data ourselves (why might this be a bad idea?), pandas lets us **merge** dataframes together using **pd.merge()**.
#
# This function finds a column with the same name that is in both dataframes and uses it as a key to match up the rows from one dataframe to the other. Then any extra columns present in dataframe two will be added into dataframe one to form a new, bigger dataframe.
#
# ![merging_merge_on_key.png](attachment:merging_merge_on_key.png)
#
# The code to do this is:
#
# ```new_dataframe = pd.merge(dataframe_one, dataframe_two)```
#
# **Which column is present in both of our dataframes?**

# %% [markdown]
# ### Now we can merge our two dataframes!
#
# ```new_dataframe = pd.merge(dataframe_one, dataframe_two)```
#
# Pandas will automatically drop any rows from the key column where values are not present in both dataframes - this means we don't have to worry about the fact that one of our datasets covers a longer time period than the other.
#
#
# **In the cell below, create a new dataframe called operations_covid by merging the cancelled and covid_cases dataframes.**

# %%
operations_covid =

# %% [markdown]
# #### Can you see the new column in the dataframe?

# %%
operations_covid.head()

# %% [markdown]
# ### Plot percentage of operations cancelled against number of recorded Covid-19 cases.
#
# We might hypothesise that an increase in Covid-19 cases could increase the percentage of operations that are cancelled. As we discussed earlier, if we want to draw a plot to look for a correlation we can use a scatter plot.
#
# ```sns.scatterplot(data = your_dataframe, x = "explanatory_column_name", y = "dependent_column_name")```
#
# In this case our explanatory variable is the number of Covid-19 cases (ReportedCases) and our dependent variable is the percentage of operations that were cancelled (PercentCancelled).
#
# **Draw an appropriately labelled scatterplot in the code cell below.**

# %% [markdown]
# Do you think reported cases and percentage of cancelled operations are correlated?
#
# If so, in what way?
#
# Why might this be the case?

# %% [markdown]
# ## Extra time?
#
# If you have finished everything above then have a think about any other aspects of the data that would be interesting to plot.
#
# Maybe you want to explore the reasons that operations are cancelled?
